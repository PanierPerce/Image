# %%
from PIL import Image

img = Image.open("greygraph.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=543x634 at 0x25D767D3940>

# %%
img.size
# Out:
# (543, 634)

# %%
out = img.resize((600,600))
out
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x25D767D90D0>

# %%
out2 = img.rotate(45)
out3 = img.rotate(288)
out3
# Out:
# <PIL.Image.Image image mode=RGB size=543x634 at 0x25D77A3E7C0>
